# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 設定目前程式資料夾路徑(務必自行更改)

# %%
folder="/content/drive/MyDrive/解密AI黑盒子分享/"

# %% [markdown]
# ## 載入所需套件

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as plt_font
twfont1=plt_font.FontProperties(fname=folder+"字型/kaiu.ttf")
from IPython import display

# %% [markdown]
# ## 載入pytorch相關套件

# %%
import torch
#建立神經網路用
import torch.nn as nn
import torch.nn.functional as F
#載入優化器
from torch import optim
#預處理資料用

# %% [markdown]
# ## 準備XOR資料集

# %%
Train_X=torch.tensor([[0,1],[1,1],[1,0],[0,0]])
Train_Y=torch.tensor([[1],[0],[1],[0]])

# %% [markdown]
# ## 建立神經網路類別

# %% [markdown]
# ## 實體化神經網路，指定損失函數和優化器

# %% [markdown]
# ## 開始訓練神經網路

# %% [markdown]
# ## 觀察訓練過程中的損失函數Loss變化

# %%
plt.figure(figsize=(8,5))
plt.title("Loss隨訓練次數的變化",fontproperties=twfont1,fontsize=20) 
plt.xlabel("訓練次數",fontproperties=twfont1,fontsize=20) 
plt.ylabel("Loss值",fontproperties=twfont1,fontsize=20)
plt.plot(Step_L,":o")
plt.show()

# %% [markdown]
# ## 鋪設x<sub>1</sub>、x<sub>2</sub>的網格點，並計劃網格點對應的預測值

# %%
x1 = np.linspace(0, 1, 100)
x2 = np.linspace(0, 1, 100)
x1,x2=np.meshgrid(x1,x2)
Yh=np.zeros(x1.shape)
net.eval()
with torch.no_grad():
  for i in range(x1.shape[0]):
    for j in range(x1.shape[1]):
      Yh[i][j]=net(torch.tensor([x1[i,j],x2[i,j]]).float())

# %% [markdown]
# ## 用等高線畫出決策邊界

# %%
plt.figure(figsize=(10,10))                
plt.title("等高線圖",fontproperties=twfont1,fontsize=15)
plt.xlabel("b",fontproperties=twfont1,fontsize=15)
plt.ylabel("w",fontproperties=twfont1,fontsize=15)
CS=plt.contour(x1,x2,Yh,20,cmap="cool")
plt.clabel(CS,inline=1,fontsize=10)
