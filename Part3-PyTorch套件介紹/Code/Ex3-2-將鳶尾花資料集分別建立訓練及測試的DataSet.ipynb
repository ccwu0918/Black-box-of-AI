# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 設定目前程式資料夾路徑(務必自行更改)

# %%
folder="/content/drive/MyDrive/解密AI黑盒子分享/"

# %% [markdown]
# ## 載入所需套件

# %%
#數據、矩陣處理套件numpy
import numpy as np

# %% [markdown]
# ## 載入pytorch相關套件

# %%
import torch
#預處理資料用
from torch.utils.data import Dataset

# %% [markdown]
# ## 建立DataSet類別

# %% [markdown]
# ## 實體化訓練和測試DataSet

# %% [markdown]
# ## 顯示測試資料集DataSet資訊

# %%
print("TrainDS資料數：",len(TrainDS))
#用迴圈讀取DataSet資料
for i in range(len(TrainDS)):
  print("特徵資料：\n",TrainDS[i][0],"分類標示：\n",TrainDS[i][1])
