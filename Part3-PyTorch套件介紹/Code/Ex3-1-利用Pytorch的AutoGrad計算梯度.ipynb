# %% [markdown]
# ## 載入pytorch套件

# %% [markdown]
# ## 產生特徵矩陣[0.0 , 1.0 , 2.0]，設定計算圖起點

# %% [markdown]
# ## 計算預估值Yh=3X<sup>2</sup>-3

# %% [markdown]
# ## 設定實際值矩陣Y=[2.0 , 4.0 , 6.0]，並計算誤差值E=Yh-Y

# %% [markdown]
# ## 計算誤差平方Z=E<sup>2</sup>

# %% [markdown]
# ## 計算損失函數L=0.5ΣZ，為計算圖終點

# %% [markdown]
# ## 反向求梯度

# %%
print("L對X的梯度", )
print("L對Z的梯度", )
print("L對E的梯度", )
print("L對Yh的梯度", )
