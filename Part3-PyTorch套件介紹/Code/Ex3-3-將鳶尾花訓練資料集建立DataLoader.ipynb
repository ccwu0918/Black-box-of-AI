# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 設定目前程式資料夾路徑(務必自行更改)

# %%
folder="/content/drive/MyDrive/解密AI黑盒子分享/"

# %% [markdown]
# ## 載入所需套件

# %%
#數據、矩陣處理套件numpy
import numpy as np

# %% [markdown]
# ## 載入pytorch相關套件

# %%
import torch
#預處理資料用
from torch.utils.data import Dataset,DataLoader

# %% [markdown]
# ## 建立DataSet類別

# %%
class MyDataset(Dataset): 
  def __init__(self,Train=True):
    data=np.loadtxt(folder+"資料集/iris_data.csv",delimiter=",")
    if Train==True:
      data=data[:100]
    else:
      data=data[100:]
    self.data = torch.tensor((data[:,:4]-data[:,:4].mean(axis=0))/data[:,:4].std(axis=0))
    self.label = torch.tensor(data[:,4])
  def __getitem__(self, index): 
    return self.data[index], self.label[index]
  def __len__(self): 
    return len(self.data)

# %% [markdown]
# ## 實體化訓練、測試資料DataSet

# %%
TrainDS=MyDataset(Train=True)
TestDS=MyDataset(Train=False)

# %% [markdown]
# ## 實體化訓練、測試資料DataLoader

# %%
# Out:
# 10

# %% [markdown]
# ## 利用迴圈取出DataLoader資料

# %% [markdown]
# ## 將DataLoader封裝成DataLoaderIter，利用迴圈取出DataLoaderIter資料
