# %% [markdown]
# ### 掛載雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### import必要的套件

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
folder="/content/drive/MyDrive/解密AI黑盒子分享/"

# %% [markdown]
# ### 從圖片檔案star1.jpg讀入資料，並劃出圖片

# %%
image = mpimg.imread(folder+"資料集/star1.jpg")
print("圖片高度：",image.shape[0],"\n圖片寬度：",image.shape[1],"\n顏色頻道：",image.shape[2])
plt.imshow(image)

# %% [markdown]
# ### 將圖片轉為灰階格式

# %%
#轉為灰階格式，RGB頻道所需權重
rgb_weights=[0.212671, 0.715160, 0.072169]
#將每一個像素的RGB數值乘以轉換權重
image_gray=np.dot(image[:,:,:3],rgb_weights)
plt.imshow(image_gray,cmap=plt.get_cmap("gray"))
print(image_gray.shape)
# Out:
# (300, 500)

# %% [markdown]
# ### 設定卷積的濾鏡Filter(3x3矩陣)

# %% [markdown]
# ### 定義卷積層的卷積運算函數

# %% [markdown]
# ### 執行卷積層處理及輸出圖象
